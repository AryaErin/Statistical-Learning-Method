# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2

# %%
fig_path = './maimai.jpg'
img = cv2.imread(fig_path)
img = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
plt.figure(figsize = (10,10))
plt.title('original image')
plt.imshow(img, cmap = 'gray')
print(img.shape)
# Out:
# (4000, 2280)

# %%
u, s, vh = np.linalg.svd(img, full_matrices=True)
print(u.shape, s.shape, vh.shape)

# %%
# 选取前k个奇异值对图像进行压缩
def imshow(u, s, vh, k):
    new_image = u[:,:k] @ np.diag(s[:k]) @ vh[:k,:]
    plt.figure(figsize = (10, 10))
    plt.title('using previous %d singular values to compress image.' % (k))
    plt.imshow(new_image, cmap = 'gray')

# %%
imshow(u, s, vh, 50)
imshow(u, s, vh, 100)
imshow(u, s, vh, 200)
